# %% [markdown]
# <a href="https://colab.research.google.com/github/ericodle/J_PlanktoNET/blob/main/VGG_finetuner_aug13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# Set up paths and parameters
data_dir = '/content/drive/MyDrive/puafolder'
image_size = 224
batch_size = 32

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


from PIL import Image

def pil_loader(path):
    try:
        img = Image.open(path)
        return img.convert("RGB")
    except Exception as e:
        print(f"Error loading image: {path} - {e}")
        return None


import os
from torch.utils.data import Dataset
from torchvision import transforms

import os
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.loader = self.pil_loader
        self.samples = self.make_samples()
        self.class_to_idx = self.find_classes()

    def pil_loader(self, path):
        try:
            img = Image.open(path)
            return img.convert("RGB")
        except Exception as e:
            print(f"Error loading image: {path} - {e}")
            return None

    def make_samples(self):
        samples = []
        for class_name in os.listdir(self.data_dir):
            class_dir = os.path.join(self.data_dir, class_name)
            if not os.path.isdir(class_dir):
                continue  # Skip non-directory entries

            for filename in os.listdir(class_dir):
                img_path = os.path.join(class_dir, filename)
                if not os.path.isfile(img_path):
                    continue  # Skip non-file entries

                samples.append((img_path, class_name))
        return samples

    def find_classes(self):
        classes = [item[1] for item in self.samples]
        classes = list(set(classes))
        classes.sort()
        class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}
        return class_to_idx

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, index):
        img_path, target_name = self.samples[index]
        img = self.loader(img_path)

        if img is None:
            return None, None

        if self.transform is not None:
            img = self.transform(img)

        target = self.class_to_idx[target_name]
        return img, target


from torch.utils.data import DataLoader

# Define transformations
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(image_size),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# Create CustomDataset instance
train_dataset = CustomDataset(data_dir=data_dir, transform=train_transform)

# Create DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
import pickle

# Save train_dataset labels to a file
with open('/content/drive/MyDrive/pua_path/train_labels.pkl', 'wb') as f:
    pickle.dump(train_dataset.samples, f)

with open('/content/drive/MyDrive/pua_path/train_labels.pkl', 'rb') as f:
    saved_samples = pickle.load(f)

# Extract class names from saved_samples
class_labels = list(set(item[1] for item in saved_samples))

print(class_labels)

num_classes = len(class_labels)
# Out:
# ['Zooplankton', 'Dinophysiales', 'ceratium', 'Hemiaulaceae', 'Dinoflagellate', 'Pennales', 'Ciliophora', 'radiolaria', 'Junk', 'pyrodinium', 'Noctilucales', 'copepods_exoskeleton_parts', 'nematoda', 'gonyaulax', 'tintinnida_alive', 'tintinnida_house', 'Ostreopsidaceae', 'Gymnodiniales', 'Peridiniales', 'Acantharea', 'Centrales', 'Oxytoxum', 'copepods_alive']

# %%
num_classes
# Out:
# 23

# %%
import torchvision.models as models

#try resnet50 next

# Load pre-trained VGG16 model
base_model = models.vgg19(pretrained=True)
num_features = base_model.classifier[6].in_features
base_model.classifier[6] = nn.Linear(num_features, num_classes)
base_model = base_model.to(device)

epochs = 20

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(base_model.parameters(), lr=0.0001)

losses = []
# Training loop
for epoch in range(epochs):
    base_model.train()
    for inputs, labels in train_loader:
        non_none_indices = [i for i, item in enumerate(inputs) if item is not None]

        if len(non_none_indices) == 0:
            continue  # Skip batch with all problematic images

        inputs = [inputs[i] for i in non_none_indices]
        labels = [labels[i] for i in non_none_indices]

        inputs = torch.stack(inputs).to(device)
        labels = torch.tensor(labels).to(device)

        optimizer.zero_grad()
        outputs = base_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    print(f"Epoch [{epoch+1}/{epochs}] - Loss: {loss.item():.4f}")

import matplotlib.pyplot as plt

plt.plot(losses, label='Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training Losses')
plt.legend()
plt.show()


# Save the trained model
torch.save(base_model.state_dict(), "/content/drive/MyDrive/pua_path/vgg16_fine_tuned.pth")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 67.3MB/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-cb9847f0aba6> in <cell line: 7>()
#       5 # Load pre-trained VGG16 model
#       6 base_model = models.resnet50(pretrained=True)
# ----> 7 num_features = base_model.classifier[6].in_features
#       8 base_model.classifier[6] = nn.Linear(num_features, num_classes)
#       9 base_model = base_model.to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1612             if name in modules:
#    1613                 return modules[name]
# -> 1614         raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615             type(self).__name__, name))
#    1616
#
# AttributeError: 'ResNet' object has no attribute 'classifier'

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import os
import shutil

output_dir = '/content/drive/MyDrive/pua_test'

test_dir = '/content/drive/MyDrive/unknown'

# Set the image size for resizing and normalization
image_size = 224

# Define the transformation for the unsorted images
unsorted_data_transforms = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load the saved model
test_model = models.vgg19(pretrained=False)
test_model.classifier[6] = nn.Linear(num_features, num_classes)
test_model.load_state_dict(torch.load('/content/drive/MyDrive/pua_path/vgg16_fine_tuned.pth'))
test_model.eval()

# Move the model to the appropriate device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
test_model = test_model.to(device)

# Get the class-to-index mapping from the dataset
class_to_idx = train_dataset.class_to_idx

# Retrieve the list of class labels
class_labels = list(class_to_idx.keys())

# Print the list of class labels
print(class_labels)

os.makedirs(output_dir, exist_ok=True)

# Iterate over the unsorted images
for filename in os.listdir(test_dir):
    image_path = os.path.join(test_dir, filename)

    try:
        img = Image.open(image_path)
    except (OSError, IOError) as e:
        print(f"Error opening {image_path}: {e}")
        continue  # Skip to the next image

    try:
        img = unsorted_data_transforms(img).unsqueeze(0).to(device)

        with torch.no_grad():
            outputs = test_model(img)
            _, preds = torch.max(outputs, 1)
            predicted_class = preds.item()

    except Exception as e:
        print(f"Error processing {image_path}: {e}")

    # Get the class name from the fine-tuning dataset
    predicted_class_name = class_labels[predicted_class]

    # Create the target class directory if it doesn't exist
    target_class_dir = os.path.join(output_dir, predicted_class_name)
    os.makedirs(target_class_dir, exist_ok=True)

    # Move the image to the corresponding class directory
    target_image_path = os.path.join(target_class_dir, filename)
    shutil.copy(image_path, target_image_path)

    print(f"Image {filename} moved to class {predicted_class_name}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ['Acantharea', 'Centrales', 'Ciliophora', 'Dinoflagellate', 'Dinophysiales', 'Gymnodiniales', 'Hemiaulaceae', 'Junk', 'Noctilucales', 'Ostreopsidaceae', 'Oxytoxum', 'Pennales', 'Peridiniales', 'Zooplankton', 'ceratium', 'copepods_alive', 'copepods_exoskeleton_parts', 'gonyaulax', 'nematoda', 'pyrodinium', 'radiolaria', 'tintinnida_alive', 'tintinnida_house']
# Image D20230712T020618_IFCB108_01586.png moved to class Dinoflagellate
# Image D20230712T031622_IFCB108_
png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_02246.png moved to class Pennales
# Image D20230711T102135_IFCB108_01850.png moved to class ceratium
# Image D20230711T061225_IFCB108_02740.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_00278.png moved to class Pennales
# Image D20230711T102135_IFCB108_01989.png moved to class Peridiniales
# Image D20230711T231856_IFCB108_00221.png moved to class Pennales
# Image D20230711T220853_IFCB108_00450.png moved to class Pennales
# Image D20230711T102135_IFCB108_00217.png moved to class Pennales
# Image D20230711T070018_IFCB108_02533.png moved to class copepods_exoskeleton_parts
# Image D20230711T102135_IFCB108_00696.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_00564.png moved to class Centrales
# Image D20230711T061225_IFCB108_02577.png moved to class Hemiaulaceae
# Image D20230712T031622_IFCB108_00936.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01998.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01442.png moved to class Peridiniales
# Image D20230712T031622_IFCB108_01318.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01583.png moved to class Pennales
# Image D20230712T020618_IFCB108_02011.png moved to class Pennales
# Image D20230712T020618_IFCB108_01276.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_01016.png moved to class Dinoflagellate
# Image D20230711T231856_IFCB108_00172.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00902.png moved to class Pennales
# Image D20230711T063656_IFCB108_01160.png moved to class Pennales
# Image D20230712T022940_IFCB108_01876.png moved to class Dinoflagellate
# Image D20230711T074702_IFCB108_00403.png moved to class Pennales
# Image D20230711T223214_IFCB108_00588.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_01920.png moved to class Pennales
# Image D20230711T072340_IFCB108_00652.png moved to class Pennales
# Image D20230711T072340_IFCB108_01495.png moved to class Pennales
# Image D20230711T072340_IFCB108_01924.png moved to class Pennales
# Image D20230712T031622_IFCB108_00898.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_01506.png moved to class ceratium
# Image D20230711T231856_IFCB108_00316.png moved to class Pennales
# Image D20230711T072340_IFCB108_00935.png moved to class Pennales
# Image D20230712T031622_IFCB108_00168.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_01029.png moved to class Centrales
# Image D20230711T063656_IFCB108_01125.png moved to class Peridiniales
# Image D20230712T022940_IFCB108_01018.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_02099.png moved to class Pennales
# Image D20230711T220853_IFCB108_00005.png moved to class Pennales
# Image D20230711T061225_IFCB108_00097.png moved to class radiolaria
# Image D20230711T231856_IFCB108_00289.png moved to class Pennales
# Image D20230711T061225_IFCB108_02220.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00359.png moved to class Junk
# Image D20230711T061225_IFCB108_00819.png moved to class Pennales
# Image D20230712T031622_IFCB108_00352.png moved to class Pennales
# Image D20230711T063656_IFCB108_00807.png moved to class Hemiaulaceae
# Image D20230712T022940_IFCB108_00399.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00805.png moved to class Dinoflagellate
# Image D20230711T225535_IFCB108_00657.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_00435.png moved to class Pennales
# Image D20230711T074702_IFCB108_01816.png moved to class Pennales
# Image D20230711T220853_IFCB108_00186.png moved to class Pennales
# Image D20230711T102135_IFCB108_02324.png moved to class ceratium
# Image D20230711T102135_IFCB108_00119.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00651.png moved to class Peridiniales
# Image D20230712T020618_IFCB108_00500.png moved to class Dinoflagellate
# Image D20230711T074702_IFCB108_01170.png moved to class Peridiniales
# Image D20230711T074702_IFCB108_02052.png moved to class Pennales
# Image D20230711T063656_IFCB108_00954.png moved to class Pennales
# Image D20230711T072340_IFCB108_00090.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_02002.png moved to class ceratium
# Image D20230711T061225_IFCB108_00716.png moved to class Pennales
# Image D20230711T063656_IFCB108_01465.png moved to class Hemiaulaceae
# Image D20230711T072340_IFCB108_00277.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00868.png moved to class Pennales
# Image D20230711T061225_IFCB108_02009.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01599.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_01526.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01833.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_00068.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00661.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_02587.png moved to class tintinnida_house
# Image D20230711T102135_IFCB108_01286.png moved to class ceratium
# Image D20230712T022940_IFCB108_01369.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01445.png moved to class Pennales
# Image D20230711T102135_IFCB108_00906.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_00126.png moved to class Pennales
# Image D20230712T022940_IFCB108_01798.png moved to class Dinoflagellate
# Image D20230711T225535_IFCB108_00539.png moved to class Pennales
# Image D20230712T020618_IFCB108_00526.png moved to class Dinoflagellate
# Image D20230711T220853_IFCB108_00088.png moved to class Pennales
# Image D20230711T061225_IFCB108_00502.png moved to class Pennales
# Image D20230711T102135_IFCB108_00461.png moved to class ceratium
# Image D20230711T072340_IFCB108_01110.png moved to class ceratium
# Error processing /content/drive/MyDrive/unknown/D20230711T074702_IFCB108_02135.png: broken data stream when reading image file
# Image D20230711T074702_IFCB108_02135.png moved to class ceratium
# Image D20230711T070018_IFCB108_02103.png moved to class Pennales
# Image D20230712T031622_IFCB108_01299.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_00490.png moved to class Pennales
# Image D20230712T022940_IFCB108_00529.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_01622.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_01949.png moved to class Pennales
# Image D20230711T061225_IFCB108_01590.png moved to class Pennales
# Image D20230711T070018_IFCB108_01780.png moved to class Pennales
# Image D20230712T020618_IFCB108_01829.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_00934.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_01935.png moved to class Pennales
# Image D20230712T020618_IFCB108_00209.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01427.png moved to class ceratium
# Image D20230711T070018_IFCB108_00523.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_01535.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_01316.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_00874.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00005.png moved to class Centrales
# Error processing /content/drive/MyDrive/unknown/D20230711T063656_IFCB108_01405.png: unrecognized data stream contents when reading image file
# Image D20230711T063656_IFCB108_01405.png moved to class Centrales
# Image D20230712T031622_IFCB108_00771.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00090.png moved to class Pennales
# Image D20230711T102135_IFCB108_02031.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_00620.png moved to class Pennales
# Image D20230711T070018_IFCB108_02023.png moved to class Pennales
# Image D20230711T102135_IFCB108_02327.png moved to class Dinoflagellate
# Image D20230712T031622_IFCB108_00346.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01217.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00657.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00297.png moved to class Dinoflagellate
# Image D20230711T074702_IFCB108_00419.png moved to class Centrales
# Image D20230711T220853_IFCB108_00289.png moved to class Zooplankton
# Image D20230711T063656_IFCB108_01916.png moved to class Dinoflagellate
# Image D20230711T074702_IFCB108_00075.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_02041.png moved to class Hemiaulaceae
# Image D20230712T022940_IFCB108_00200.png moved to class Centrales
# Image D20230711T225535_IFCB108_00551.png moved to class Pennales
# Image D20230711T074702_IFCB108_01165.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01322.png moved to class Pennales
# Image D20230712T031622_IFCB108_00347.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00118.png moved to class Peridiniales
# Image D20230711T102135_IFCB108_02254.png moved to class Pennales
# Image D20230711T102135_IFCB108_01830.png moved to class Pennales
# Image D20230711T102135_IFCB108_02215.png moved to class ceratium
# Image D20230712T022940_IFCB108_00249.png moved to class Dinoflagellate
# Image D20230711T074702_IFCB108_02157.png moved to class Hemiaulaceae
# Image D20230711T063656_IFCB108_01305.png moved to class Pennales
# Image D20230711T102135_IFCB108_00903.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_00136.png moved to class Centrales
# Image D20230712T022940_IFCB108_00545.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_01900.png moved to class Ostreopsidaceae
# Image D20230711T102135_IFCB108_00250.png moved to class Pennales
# Image D20230711T231856_IFCB108_00727.png moved to class Pennales
# Image D20230711T072340_IFCB108_01204.png moved to class Pennales
# Image D20230712T022940_IFCB108_00907.png moved to class Dinoflagellate
# Image D20230712T031622_IFCB108_00466.png moved to class Pennales
# Image D20230712T022940_IFCB108_00774.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01287.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01423.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_02821.png moved to class Pennales
# Image D20230711T223214_IFCB108_00631.png moved to class Pennales
# Image D20230711T223214_IFCB108_00520.png moved to class Pennales
# Image D20230711T061225_IFCB108_00183.png moved to class tintinnida_alive
# Image D20230711T074702_IFCB108_02027.png moved to class Pennales
# Image D20230711T070018_IFCB108_01593.png moved to class Dinoflagellate
# Image D20230711T223214_IFCB108_00385.png moved to class Peridiniales
# Image D20230712T020618_IFCB108_00027.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01980.png moved to class Pennales
# Image D20230712T020618_IFCB108_00657.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_00261.png moved to class Hemiaulaceae
# Image D20230711T102135_IFCB108_02476.png moved to class Pennales
# Image D20230711T063656_IFCB108_01314.png moved to class Pennales
# Image D20230711T102135_IFCB108_00609.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_01902.png moved to class Peridiniales
# Image D20230711T102135_IFCB108_01388.png moved to class Peridiniales
# Image D20230711T225535_IFCB108_00437.png moved to class Pennales
# Image D20230711T061225_IFCB108_01933.png moved to class ceratium
# Image D20230711T063656_IFCB108_01468.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_01183.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_00053.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_00763.png moved to class Dinoflagellate
# Image D20230711T225535_IFCB108_00921.png moved to class Pennales
# Image D20230711T102135_IFCB108_02445.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_01781.png moved to class ceratium
# Image D20230711T072340_IFCB108_01550.png moved to class ceratium
# Image D20230711T231856_IFCB108_00521.png moved to class Pennales
# Image D20230711T070018_IFCB108_02521.png moved to class Acantharea
# Image D20230711T070018_IFCB108_01903.png moved to class Pennales
# Image D20230711T061225_IFCB108_00550.png moved to class Pennales
# Image D20230712T020618_IFCB108_01168.png moved to class Dinoflagellate
# Image D20230711T102135_IFCB108_01168.png moved to class Dinoflagellate
# Image D20230711T063656_IFCB108_01054.png moved to class Pennales
# Image D20230711T102135_IFCB108_01859.png moved to class Oxytoxum
# Image D20230711T061225_IFCB108_00762.png moved to class Pennales
# Image D20230711T070018_IFCB108_00770.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_01339.png moved to class Hemiaulaceae
# Image D20230711T061225_IFCB108_02086.png moved to class Pennales
# Image D20230712T022940_IFCB108_01366.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_00563.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_00296.png moved to class Pennales
# Image D20230712T022940_IFCB108_00190.png moved to class tintinnida_house
# Image D20230711T072340_IFCB108_01877.png moved to class Pennales
# Image D20230712T020618_IFCB108_01545.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_00581.png moved to class Pennales
# Image D20230712T031622_IFCB108_01229.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_01330.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_00978.png moved to class Pennales
# Image D20230712T022940_IFCB108_00352.png moved to class Pennales
# Image D20230711T102135_IFCB108_01357.png moved to class ceratium
# Image D20230711T061225_IFCB108_02686.png moved to class Peridiniales
# Image D20230712T020618_IFCB108_01251.png moved to class Dinoflagellate
# Image D20230711T072340_IFCB108_00429.png moved to class Dinoflagellate
# Image D20230712T031622_IFCB108_01021.png moved to class Dinoflagellate
# Image D20230711T061225_IFCB108_00442.png moved to class Pennales
# Image D20230711T072340_IFCB108_00502.png moved to class Pennales
# Image D20230712T020618_IFCB108_00779.png moved to class Dinoflagellate
# Image D20230712T022940_IFCB108_01078.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_01733.png moved to class Pennales
# Image D20230712T022940_IFCB108_00208.png moved to class Dinoflagellate
# Image D20230712T031622_IFCB108_00155.png moved to class Dinoflagellate
# Image D20230712T020618_IFCB108_00534.png moved to class Dinoflagellate
# Image D20230711T070018_IFCB108_01909.png moved to class tintinnida_house
# Image D20230711T102135_IFCB108_00112.png moved to class Pennales
